# %% [markdown]
# # Interpretable Poker AI Analysis
#
# This notebook provides interactive exploration and analysis of the interpretable poker AI decision trees.
#
# ## Overview
# - Load and display decision trees
# - Show example decision paths
# - Compare interpretable vs neural network performance
# - Generate strategy charts and opening ranges

# %%
# Import required libraries
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import export_text
import joblib

# Add src to path
sys.path.append(os.path.join('..', 'src'))

from interpretable.tree_trainer import InterpretableTreeTrainer
from interpretable.interpretable_agent import InterpretablePokerAgent
from interpretable.feature_extractor import get_feature_names
from interpretable.visualizer import visualize_tree, export_tree_as_markdown

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import numpy as np
#       6 import matplotlib.pyplot as plt
# ----> 7 import seaborn as sns
#       8 from sklearn.tree import export_text
#       9 import joblib
#
# ModuleNotFoundError: No module named 'seaborn'
